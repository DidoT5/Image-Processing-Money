# %%
from detector_monedas import *
from funciones_auxiliares import *

# %%
def monedas_ejemplo(ruta="monedas_ejemplo/*"):
    monedas = glob.glob(ruta)
    X = []
    for moneda in monedas:
        X.append(cargaImagen(moneda))    
    return X

X = monedas_ejemplo()

# %%
muestraMultiplesImagenes(X)

# %%
detector = detectorMonedas()

# %%
detector.predecir(X)
# Out:
# [2, 0.05, 1, 0.1, 0.2, 0.1, 0.2]
