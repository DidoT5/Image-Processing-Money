# %%
from segmentador_clasificador import *

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv.imread("monYbil.jpeg")
rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.show()

# %%
image2 = cv.imread("imagen61.jpg")
rgb2 = cv.cvtColor(image2, cv.COLOR_BGR2RGB)
plt.imshow(rgb2)
plt.show()

# %%
image3 = cv.imread("monedas.jpeg")
rgb3 = cv.cvtColor(image3, cv.COLOR_BGR2RGB)
plt.imshow(rgb3)
plt.show()

# %%
res = contadorDinero(image,showSegmentacion=True)
# Out:
# [7 4 6 4 4 4]
# ### BILLETES DETECTADOS ###
# Se ha detectado un billete de 5 euros
#
# ### MONEDAS DETECTADAS ###
# Se ha detectado una moneda de 0.1 euros
# Se ha detectado una moneda de 1 euros
# Se ha detectado una moneda de 0.05 euros
# Se ha detectado una moneda de 1 euros
# Se ha detectado una moneda de 1 euros
# Se ha detectado una moneda de 1 euros
#
# El valor total ha sido de: 9.149999999999999 euros

# %%
res = contadorDinero(rgb2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-d6a1c6588303> in <module>
# ----> 1 res = contadorDinero(rgb2)
#
# ~\OneDrive\Escritorio\Universidad-USB\4º De Carrera - Ingeniería Informática T.I\Procesamiento de Imágenes Digitales\Trabajo\ws\segmentador_clasificador.py in contadorDinero(img, descripcion, showSegmentacion)
#      34             clasifBilletes.append(res)
#      35
# ---> 36     clasifMonedas = clasificadorMoneda.predecir(monedas)
#      37
#      38     valorTotal = sum(clasifBilletes+clasifMonedas)
#
# ~\OneDrive\Escritorio\Universidad-USB\4º De Carrera - Ingeniería Informática T.I\Procesamiento de Imágenes Digitales\Trabajo\ws\detector_monedas.py in predecir(self, X)
#      69
#      70     def predecir(self,X):
# ---> 71         processed = self.preprocess_coins(X)
#      72         logits = self.model.predict(processed)
# ...

# %%
res = contadorDinero(rgb3)
# Out:
# [6 9 6 6 6]
# ### BILLETES DETECTADOS ###
#
# ### MONEDAS DETECTADAS ###
# Se ha detectado una moneda de 0.05 euros
# Se ha detectado una moneda de 0.5 euros
# Se ha detectado una moneda de 0.05 euros
# Se ha detectado una moneda de 0.05 euros
# Se ha detectado una moneda de 0.05 euros
#
# El valor total ha sido de: 0.7000000000000002 euros

# %%
def monedas_ejemplo(ruta="monedas_ejemplo/*"):
    monedas = glob.glob(ruta)
    X = []
    for moneda in monedas:
        X.append(cargaImagen(moneda))    
    return X

X = monedas_ejemplo()

# %%
muestraMultiplesImagenes(X)

# %%
image3 = cv.imread("solobilletes.jpeg")
rgb3 = cv.cvtColor(image3, cv.COLOR_BGR2RGB)
plt.imshow(rgb3)
plt.show()

# %%
image3 = cv.imread("solomonedas.JPG")
rgb3 = cv.cvtColor(image3, cv.COLOR_BGR2RGB)
plt.imshow(rgb3)
plt.show()

# %%
res = contadorDinero(image3, showSegmentacion=True)
# Out:
# [7 7]
# ### BILLETES DETECTADOS ###
#
# ### MONEDAS DETECTADAS ###
# Se ha detectado una moneda de 0.1 euros
# Se ha detectado una moneda de 0.1 euros
#
# El valor total ha sido de: 0.2 euros
